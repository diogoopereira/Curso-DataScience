# %%
# !pip install igraph
from igraph import Graph
from igraph import plot
# Out:
# Requirement already satisfied: igraph in /usr/local/lib/python3.10/dist-packages (0.11.8)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph) (1.7.0)

# %%
#Definição do grado com arrestas
grafo1 = Graph(edges = [(0,1),(0,2),(0,3)],directed = True)
#Definiçãodo rotulo de cada vertice
grafo1.vs['label'] = range(grafo1.vcount())
print(grafo1)
# Out:
# IGRAPH D--- 4 3 --
# + attr: label (v)
# + edges:
# 0->1 0->2 0->3

# %%
#Grafico
plot(grafo1,bbox = (0,0,300,300))

# %%
#Criação do segundo grafo
grafo2 = Graph(edges = [(0,1),(1,2),(2,3),(3,0),(3,2),(2,1),(1,0)],directed = True)
grafo2.vs['label'] = range(grafo2.vcount())
print(grafo2)
# Out:
# IGRAPH D--- 4 7 --
# + attr: label (v)
# + edges:
# 0->1 1->2 2->3 3->0 3->2 2->1 1->0

# %%
#Grafo com laço
grafo3 = Graph(edges = [(0,1),(1,2),(2,3),(3,0),(1,1)],directed = True)
grafo3.vs['label'] = range(grafo3.vcount())
print(grafo3)
# Out:
# IGRAPH D--- 4 5 --
# + attr: label (v)
# + edges:
# 0->1 1->2 2->3 3->0 1->1

# %%
#Criação do quarto grafo
grafo4 = Graph(edges = [(0,1),(1,2),(2,3),(3,0),(1,1)],directed = True)
#Adicionamos vertices isolados
grafo4.add_vertex(5)
grafo4.vs['label'] = range(grafo4.vcount())
print(grafo4)
# Out:
# IGRAPH DN-- 5 5 --
# + attr: label (v), name (v)
# + edges (vertex names):
# None->None, None->None, None->None, None->None, None->None
# <ipython-input-33-a46f7b72fe5b>:4: DeprecationWarning: You are using integers as vertex names. This is discouraged because most igraph functions interpret integers as vertex _IDs_ and strings as vertex names. For sake of consistency, convert your vertex names to strings before assigning them. Future versions from igraph 0.11.0 will disallow integers as vertex names.
#   grafo4.add_vertex(5)
