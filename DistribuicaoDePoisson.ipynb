# %%
from scipy.stats import poisson

# %%
#Qual a probabilidade de acontecer 3 acidentes no dia?
poisson.pmf(3, 2)
# Out:
# 0.18044704431548356

# %%
#Qual a probabilidade de ocorrerem 3 ou menos acidentes no dia?
poisson.cdf(3, 2)
# Out:
# 0.857123460498547

# %%
poisson.sf(3, 2)
# Out:
# 0.14287653950145296
