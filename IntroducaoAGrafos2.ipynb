# %%
# !pip install igraph
from igraph import Graph
from igraph import plot
# Out:
# Collecting igraph
#   Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting texttable>=1.6.2 (from igraph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading igraph-0.11.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.2 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-0.11.8 texttable-1.7.0

# %%
#Grafo direcionado
grafo1 = Graph(edges = [(0,1),(2,2),(2,3),(3,0)],directed = True)
grafo1.vs['label'] = range(grafo1.vcount())
print(grafo1)
# Out:
# IGRAPH D--- 4 4 --
# + attr: label (v)
# + edges:
# 0->1 2->2 2->3 3->0

# %%
#Criação não direcionada
grafo2 = Graph(edges = [(0,1),(1,2),(2,3),(3,0)],directed = False)
grafo2.vs['label'] = range(grafo2.vcount())
print(grafo2)
# Out:
# IGRAPH U--- 4 4 --
# + attr: label (v)
# + edges:
# 0--1 1--2 2--3 0--3

# %%
#Adicionando vertices e arrestas por meio das funções add_vertices e add_vertex
grafo3 = Graph(directed = False)
grafo3.add_vertices(10)
grafo3.add_vertex(16)
grafo3.add_edges([(0,1),(2,2),(2,3),(3,0)])
grafo3.vs['label'] = range(grafo3.vcount())
print(grafo3)
# Out:
# IGRAPH UN-- 11 4 --
# + attr: label (v), name (v)
# + edges (vertex names):
# None--None, None--None, None--None, None--None
# <ipython-input-5-43e18516601d>:4: DeprecationWarning: You are using integers as vertex names. This is discouraged because most igraph functions interpret integers as vertex _IDs_ and strings as vertex names. For sake of consistency, convert your vertex names to strings before assigning them. Future versions from igraph 0.11.0 will disallow integers as vertex names.
#   grafo3.add_vertex(16)

# %%
#Criação do quarto grafo, configurando rotulos personalizados para os vertices
grafo4 = Graph(directed = False)
grafo4.add_vertices(5)
grafo4.add_edges([(0,1),(1,2),(2,3),(3,4),(4,0),(0,2),(2,1)])
grafo4.add_vertex(5)
grafo4.add_vertex(6)
grafo4.vs['label'] = ['A','B','C','D','E','F','G']
print(grafo4)
# Out:
# IGRAPH UN-- 7 7 --
# + attr: label (v), name (v)
# + edges (vertex names):
# None--None, None--None, None--None, None--None, None--None, None--None,
# None--None
# <ipython-input-6-f3866afd2479>:5: DeprecationWarning: You are using integers as vertex names. This is discouraged because most igraph functions interpret integers as vertex _IDs_ and strings as vertex names. For sake of consistency, convert your vertex names to strings before assigning them. Future versions from igraph 0.11.0 will disallow integers as vertex names.
#   grafo4.add_vertex(5)
# <ipython-input-6-f3866afd2479>:6: DeprecationWarning: You are using integers as vertex names. This is discouraged because most igraph functions interpret integers as vertex _IDs_ and strings as vertex names. For sake of consistency, convert your vertex names to strings before assigning them. Future versions from igraph 0.11.0 will disallow integers as vertex names.
#   grafo4.add_vertex(6)
