# %%
from scipy.stats import binom

# %%
#Jogar uma moeda 5 vezes, qual a probabilidade de dar cara 3 vezes?
#eventos, experimentos, probabilidade
prob = binom.pmf(3, 5, 0.5)
prob
# Out:
# 0.31249999999999983

# %%
#Passar por 4 sinais de 4 tempos, qual a probabilidade de pegar sinal verde
#Nenhuma, 2 vezes, 3 vezes, 4 vezes
binom.pmf(0, 4, 0.23) + binom.pmf(1, 4, 0.23) + binom.pmf(2, 4, 0.23) + binom.pmf(3, 4, 0.23) + binom.pmf(4, 4, 0.23)
# Out:
# 1.0000000000000007

# %%
#E se forem sinais de dois tempo?
binom.pmf(4, 4, 0.5)
# Out:
# 0.0625

# %%
#Probabilidade acumulativa
binom.cdf(4, 4, 0.25)
# Out:
# 1.0

# %%
#Concurso com 12 questões, qual a probabilidade de acertar 7 questões considerando
# que cada questão tem 4 alternativas?
binom.pmf(7, 12, 0.25) * 100
# Out:
# 1.1471271514892587

# %%
#Probabilidade de acertar as 12 questões
binom.pmf(12, 12, 0.25) * 100
# Out:
# 5.9604644775390625e-06
